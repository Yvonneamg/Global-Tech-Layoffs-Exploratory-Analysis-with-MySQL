# %%
# %pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-26.7.0-py2.py3-none-any.whl.metadata (11 kB)
# Using cached mysql_connector_python-26.7.0-py2.py3-none-any.whl (480 kB)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-26.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

print(sys.executable)
print(sys.version)

import mysql.connector
import pandas as pd
# Out:
# c:\Users\HP\anaconda3\python.exe
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
conn = mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Phoenix@261997",
    database="world_tech_layoff"
)

# %%
query = """
SELECT *
FROM layoff_staging;
"""

selected_data = pd.read_sql(query, conn)
selected_data


#print(selected_data.head())

#conn.close()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11820\1005406861.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   selected_data = pd.read_sql(query, conn)
#             company        location total_laid_off       date  \
# 0              Kyte     SF Bay Area                 8/15/2025
# 1     Restaurant365     Los Angeles          100.0  8/14/2025
# 2            Oracle     SF Bay Area          188.0  8/13/2025
# 3            Oracle         Seattle          161.0  8/13/2025
# 4                F5         Seattle          106.0  8/13/2025
# ...             ...             ...            ...        ...
# 4130        Service     Los Angeles                 3/16/2020
# 4131   HopSkipDrive     Los Angeles            8.0  3/13/2020
# 4132    Panda Squad     SF Bay Area            6.0  3/13/2020
# 4133  Tamara Mellon     Los Angeles           20.0  3/12/2020
# 4134       EasyPost  Salt Lake City           75.0  3/11/2020
#
#      percentage_laid_off        industry  \
# 0                   100%  Transportation
# 1                     9%            Food
# 2                                  Other
# 3                                  Other
# 4                     2%        Security
# ...                  ...             ...
# 4130                100%          Travel
# 4131                 10%  Transportation
# 4132                 75%        Consumer
# 4133                 40%          Retail
# 4134                           Logistics
#
#                                                  source     stage  \
# 0     https://techcrunch.com/2025/08/15/kyte-which-b...   Unknown
# 1     https://www.restaurantbusinessonline.com/techn...  Series C
# 2     https://www.sfchronicle.com/tech/article/oracl...  Post-IPO
# 3     https://www.geekwire.com/2025/oracle-lays-off-...  Post-IPO
# 4     https://www.geekwire.com/2024/f5-confirms-new-...  Post-IPO
# ...                                                 ...       ...
# 4130  https://techcrunch.com/2020/03/16/travel-savin...      Seed
# 4131  https://layoffs.fyi/2020/04/02/hopskipdrive-la...   Unknown
# 4132  https://twitter.com/danielsinger/status/123854...      Seed
# 4133            https://layoffs.fyi/list/tamara-mellon/  Series C
# 4134  https://www.bizjournals.com/louisville/news/20...  Series A
#
#      funds_raised        country date_added
# 0            $548  United States  8/18/2025
# 1            $127  United States  8/18/2025
# 2                  United States  8/18/2025
# 3                  United States  8/18/2025
# 4                  United States  8/18/2025
# ...           ...            ...        ...
# 4130           $5  United States  8/31/2020
# 4131          $45  United States   4/3/2020
# 4132           $1  United States  4/17/2020
# 4133          $90  United States  3/31/2020
# 4134          $12  United States  3/31/2020
#
# [4135 rows x 11 columns]
